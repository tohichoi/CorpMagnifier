# %%
import pandas as pd
from pathlib import Path

# %%
Path('data').exists()
# Out:
# True

# %%
root = Path('data/archive/utf-8/손익계산서')
prev_parent = None

def csv_error_handler(bad_line: list[str]) -> list[str] | None :
    print(bad_line)
    return None

assert(callable(csv_error_handler))
       
for f in root.rglob('*.txt'):
    df = pd.read_csv(f, sep='\t', thousands=',', engine="python", on_bad_lines=csv_error_handler)
    headers=','.join(list(df.columns))
    if prev_parent != f.parent:
        prev_parent = f.parent
        print(f.parent)
    print(headers)
# Out:
# data/archive/utf-8/손익계산서
# 재무제표종류,종목코드,회사명,시장구분,업종,업종명,결산월,결산기준일,보고서종류,통화,항목코드,항목명,당기 반기 3개월,당기 반기 누적,전기 반기 3개월,전기 반기 누적,전기,전전기
# 재무제표종류,종목코드,회사명,시장구분,업종,업종명,결산월,결산기준일,보고서종류,통화,항목코드,항목명,당기 반기 3개월,당기 반기 누적,전기 반기 3개월,전기 반기 누적,전기,전전기
# 재무제표종류,종목코드,회사명,시장구분,업종,업종명,결산월,결산기준일,보고서종류,통화,항목코드,항목명,당기 3분기 3개월,당기 3분기 누적,전기 3분기 3개월,전기 3분기 누적,전기,전전기
# 재무제표종류,종목코드,회사명,시장구분,업종,업종명,결산월,결산기준일,보고서종류,통화,항목코드,항목명,당기 1분기 3개월,당기 1분기 누적,전기 1분기 3개월,전기 1분기 누적,전기,전전기
# 재무제표종류,종목코드,회사명,시장구분,업종,업종명,결산월,결산기준일,보고서종류,통화,항목코드,항목명,당기 반기 3개월,당기 반기 누적,전기 반기 3개월,전기 반기 누적,전기,전전기
# 재무제표종류,종목코드,회사명,시장구분,업종,업종명,결산월,결산기준일,보고서종류,통화,항목코드,항목명,당기 3분기 3개월,당기 3분기 누적,전기 3분기 3개월,전기 3분기 누적,전기,전전기
# 재무제표종류,종목코드,회사명,시장구분,업종,업종명,결산월,결산기준일,보고서종류,통화,항목코드,항목명,Unnamed: 12,당기,Unnamed: 14,Unnamed: 15,전기,전전기,Unnamed: 18
# 재무제표종류,종목코드,회사명,시장구분,업종,업종명,결산월,결산기준일,보고서종류,통화,항목코드,항목명,당기 3분기 3개월,당기 3분기 누적,전기 3분기 3개월,전기 3분기 누적,전기,전전기
# 재무제표종류,종목코드,회사명,시장구분,업종,업종명,결산월,결산기준일,보고서종류,통화,항목코드,항목명,Unnamed: 12,당기,Unnamed: 14,Unnamed: 15,전기,전전기,Unnamed: 18
# ...

# %%
f = Path('data/archive/utf-8/현금흐름표/2019_사업보고서_04_현금흐름표_연결_20230524.txt')
df = pd.read_csv(f, sep='\t', thousands=',', engine="python")
[ c for c in df.columns if 'unnamed' in c.lower() ]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[18], line 2
#       1 f = Path('data/archive/utf-8/현금흐름표/2019_사업보고서_04_현금흐름표_연결_20230524.txt')
# ----> 2 df = pd.read_csv(f, sep='\t', thousands=',', engine="python")
#       3 [ c for c in df.columns if 'unnamed' in c.lower() ]
#
# ...

# %%
df
# Out:
#                     재무제표종류      종목코드    회사명        시장구분   업종            업종명
# 0      현금흐름표, 간접법 - 연결재무제표  [060310]     3S   코스닥시장상장법인  292  특수 목적용 기계 제조업  \
# 1      현금흐름표, 간접법 - 연결재무제표  [060310]     3S   코스닥시장상장법인  292  특수 목적용 기계 제조업
# 2      현금흐름표, 간접법 - 연결재무제표  [060310]     3S   코스닥시장상장법인  292  특수 목적용 기계 제조업
# 3      현금흐름표, 간접법 - 연결재무제표  [060310]     3S   코스닥시장상장법인  292  특수 목적용 기계 제조업
# 4      현금흐름표, 간접법 - 연결재무제표  [060310]     3S   코스닥시장상장법인  292  특수 목적용 기계 제조업
# ...                    ...       ...    ...         ...  ...            ...
# 21517  현금흐름표, 간접법 - 연결재무제표  [049770]  동원F&B  유가증권시장상장법인  107      기타 식품 제조업
# 21518  현금흐름표, 간접법 - 연결재무제표  [049770]  동원F&B  유가증권시장상장법인  107      기타 식품 제조업
# 21519  현금흐름표, 간접법 - 연결재무제표  [049770]  동원F&B  유가증권시장상장법인  107      기타 식품 제조업
# 21520  현금흐름표, 간접법 - 연결재무제표  [049770]  동원F&B  유가증권시장상장법인  107      기타 식품 제조업
# 21521  현금흐름표, 간접법 - 연결재무제표  [049770]  동원F&B  유가증권시장상장법인  107      기타 식품 제조업
#
#        결산월       결산기준일  보고서종류   통화
# ...
